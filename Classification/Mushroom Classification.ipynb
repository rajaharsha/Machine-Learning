# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("mushrooms.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
# give the prediction column name
prediction_column = 'class' 

prediction_data = data[prediction_column]
features_data = data.drop('class', axis=1)

# %%
feature_columns = feature_data.columns

# transform the categorical features into binary features
binary_features = pd.get_dummies(features_data[feature_columns])

# concat categorical features data with original data
features_data = pd.concat([features_data, binary_features], axis=1)
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape    ...    population_s population_v  \
# 0         n          k           e    ...               1            0
# 1         b          k           e    ...               0            0
# 2         b          n           e    ...               0            0
# 3         n          n           e    ...               1            0
# 4         b          k           t    ...               0            0
#
#   population_y habitat_d habitat_g habitat_l habitat_m habitat_p habitat_u  \
# ...

# %%
# transform the categorical features into binary features
cat_features = prediction_features.columns
cat_features
# Out:
# Index([], dtype='object')

# %%
features_data = pd.concat([features_data, pd.get_dummies(features_data[feature_columns])], axis=1)

# %%
#pd.to_csv(features_data, 'features_data.csv')
features_data.to_csv('features_data.csv')
